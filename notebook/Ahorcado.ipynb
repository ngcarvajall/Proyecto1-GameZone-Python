# %%
import random
### La buena
dibujo_ahorcado = [
    '''
       +---+
       |   |
           |
           |
           |
           |
    =========
    ''',
    '''
       +---+
       |   |
       O   |
           |
           |
           |
    =========
    ''',
    '''
       +---+
       |   |
       O   |
       |   |
           |
           |
    =========
    ''',
    '''
       +---+
       |   |
       O   |
      /|   |
           |
           |
    =========
    ''',
    '''
       +---+
       |   |
       O   |
      /|\  |
           |
           |
    =========
    ''',
    '''
       +---+
       |   |
       O   |
      /|\  |
      /    |
           |
    =========
    ''',
]

lista_palabras = ['frikeo', 'python', 'hackio','cosinchis']

palabra_elegida = list(random.choice(lista_palabras))
palabra_oculta =['_']*len(palabra_elegida)
num_intentos = 6
lista_abecedario = list('abcdefghijklmnñopqrstuvwxyz')
letras_descartadas = []

def mostrar_estado(intentos, descartes,ocultas,dibujo):

    print(f'Intentos restantes: {intentos}')
    print(f'Letras descartadas: {", ".join(descartes)}\n')
    print(f'Palabra: {" ".join(ocultas)}\n')
    print(dibujo[6 - intentos])


def opcion_letra(letra, abecedario,pal_oculta,let_descartadas):
    if len(letra) != 1:
        print('Has seleccionado más de una letra')
        return False
    elif letra not in abecedario:
        print('Has seleccionado una letra fuera del abecedario')
        return False
    elif letra in pal_oculta:
        print('Esta letra ya la has acertado')
        return True
    elif letra in let_descartadas:
        print('Esta letra ya la habías dicho')
        return False
    else:
        return True

def gestion(letra):
        for i in range(len(palabra_elegida)):
            if palabra_elegida[i] == letra:
                palabra_oculta[i] = letra
                palabra_elegida[i] = '_'

print('BIENVENIDO AL JUEGO DEL AHORCADO, Hackio Edition 😎 \n')
print('Reglas del juego: Introduce letras para adivinar la palabra oculta .')
print(f'Tienes {num_intentos} intentos. ¡Buena suerte!')

while num_intentos > 0 and '_' in palabra_oculta:
    mostrar_estado(num_intentos,letras_descartadas,palabra_oculta,dibujo_ahorcado)
    print('-----')
    letra_elegida = input('Introduce una letra:').lower()

    while not opcion_letra(letra_elegida, lista_abecedario, palabra_oculta,letras_descartadas):
        letra_elegida = input('Introduce otra letra').lower()

    if letra_elegida in palabra_elegida:
       gestion(letra_elegida)
       print('Has acertado la letra')
    else: 
        print('Te has equivocado chaval')
        letras_descartadas.append(letra_elegida)
        num_intentos -= 1
        ### debo de agregar la visual del ahorcado (hago un contador de la lista de dibujos que vaya aumentando )
        ### me falta imprimir la palabra completa
if '_' not in palabra_oculta: ### agregar que cuando los intentos y el contador sean iguales, se pierde
    print('\n🏆¡ENHORABUENA!🏆\n🏆¡HAS GANADO EL JUEGO!🏆')
    mostrar_estado(num_intentos,letras_descartadas,palabra_oculta,dibujo_ahorcado)
else:
    mostrar_estado(num_intentos,letras_descartadas,palabra_oculta,dibujo_ahorcado)
    print(f'\n ¡Mejor suerte la próxima!'
        '''\n
       +---+
       |   |
      💀   |
      /|\  |
      / \  |
           |
    =========
    ''')
# Out:
# BIENVENIDO AL JUEGO DEL AHORCADO, Hackio Edition 😎
#
# Reglas del juego: Introduce letras para adivinar la palabra oculta .
# Tienes 6 intentos. ¡Buena suerte!
# Intentos restantes: 6
# Letras descartadas:
#
# Palabra: _ _ _ _ _ _ _ _ _
#
#
#        +---+
#        |   |
#            |
#            |
#            |
#            |
#     =========
#
# -----
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra

# %%
import random
### prueba
dibujo_ahorcado = [
    '''
       +---+
       |   |
           |
           |
           |
           |
    =========
    ''',
    '''
       +---+
       |   |
       O   |
           |
           |
           |
    =========
    ''',
    '''
       +---+
       |   |
       O   |
       |   |
           |
           |
    =========
    ''',
    '''
       +---+
       |   |
       O   |
      /|   |
           |
           |
    =========
    ''',
    '''
       +---+
       |   |
       O   |
      /|\  |
           |
           |
    =========
    ''',
    '''
       +---+
       |   |
       O   |
      /|\  |
      /    |
           |
    =========
    ''',
]

lista_palabras = ['frikeo', 'python', 'hackio','cosinchis']

palabra_elegida = list(random.choice(lista_palabras))
palabra_oculta =['_']*len(palabra_elegida)
num_intentos = 6
lista_abecedario = list('abcdefghijklmnñopqrstuvwxyz')
letras_descartadas = []

def mostrar_estado(intentos, descartes,ocultas,dibujo):

    print(f'Intentos restantes: {intentos}')
    print(f'Letras descartadas: {", ".join(descartes)}\n')
    print(f'Palabra: {" ".join(ocultas)}\n')
    print(dibujo[6 - intentos])


def opcion_letra(letra, abecedario,pal_oculta,let_descartadas):
    if len(letra) != 1:
        print('Has seleccionado más de una letra')
        return False
    elif letra not in abecedario:
        print('Has seleccionado una letra fuera del abecedario')
        return False
    elif letra in pal_oculta:
        print('Esta letra ya la has acertado')
        return True
    elif letra in let_descartadas:
        print('Esta letra ya la habías dicho')
        return False
    else:
        return True

def gestion(letra):
        for i in range(len(palabra_elegida)):
            if palabra_elegida[i] == letra:
                palabra_oculta[i] = letra
                palabra_elegida[i] = '_'

print('BIENVENIDO AL JUEGO DEL AHORCADO, Hackio Edition 😎 \n')
print('Reglas del juego: Introduce letras para adivinar la palabra oculta .')
print(f'Tienes {num_intentos} intentos. ¡Buena suerte!')

while num_intentos > 0 and '_' in palabra_oculta:
    mostrar_estado(num_intentos,letras_descartadas,palabra_oculta,dibujo_ahorcado)
    print('-----')
    letra_elegida = input('Introduce una letra:').lower()

    while not opcion_letra(letra_elegida, lista_abecedario, palabra_oculta,letras_descartadas):
        letra_elegida = input('Introduce otra letra').lower()

    if letra_elegida in palabra_elegida:
       gestion(letra_elegida)
       print('Has acertado la letra')
    else: 
        print('Te has equivocado chaval')
        letras_descartadas.append(letra_elegida)
        num_intentos -= 1
        ### debo de agregar la visual del ahorcado (hago un contador de la lista de dibujos que vaya aumentando )
        ### me falta imprimir la palabra completa
if '_' not in palabra_oculta: ### agregar que cuando los intentos y el contador sean iguales, se pierde
    print('\n🏆¡ENHORABUENA!🏆\n🏆¡HAS GANADO EL JUEGO!🏆')
    mostrar_estado(num_intentos,letras_descartadas,palabra_oculta,dibujo_ahorcado)
else:
    mostrar_estado(num_intentos,letras_descartadas,palabra_oculta,dibujo_ahorcado)
    print(f'\n ¡Mejor suerte la próxima!'
        '''\n
       +---+
       |   |
      💀   |
      /|\  |
      / \  |
           |
    =========
    ''')
# Out:
# BIENVENIDO AL JUEGO DEL AHORCADO, Hackio Edition 😎
#
# Reglas del juego: Introduce letras para adivinar la palabra oculta .
# Tienes 6 intentos. ¡Buena suerte!
# Intentos restantes: 6
# Letras descartadas:
#
# Palabra: _ _ _ _ _ _ _ _ _
#
#
#        +---+
#        |   |
#            |
#            |
#            |
#            |
#     =========
#
# -----
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has seleccionado más de una letra
# Has acertado la letra
# Intentos restantes: 6
# Letras descartadas:
#
# Palabra: _ _ _ _ _ _ h _ _
#
#
#        +---+
#        |   |
#            |
#            |
#            |
#            |
#     =========
#
# -----
# Has seleccionado más de una letra
# Te has equivocado chaval
# Intentos restantes: 5
# Letras descartadas: d
#
# Palabra: _ _ _ _ _ _ h _ _
#
#
#        +---+
#        |   |
#        O   |
#            |
#            |
#            |
#     =========
#
# -----
# Esta letra ya la habías dicho
# Esta letra ya la habías dicho
# Esta letra ya la habías dicho
# Esta letra ya la habías dicho
# Esta letra ya la habías dicho
# Esta letra ya la habías dicho
# Esta letra ya la habías dicho
# Has acertado la letra
# Intentos restantes: 5
# Letras descartadas: d
#
# Palabra: _ _ s _ _ _ h _ s
#
#
#        +---+
#        |   |
#        O   |
#            |
#            |
#            |
#     =========
#
# -----
# Esta letra ya la has acertado
# Te has equivocado chaval
# Intentos restantes: 4
# Letras descartadas: d, s
#
# Palabra: _ _ s _ _ _ h _ s
#
#
#        +---+
#        |   |
#        O   |
#        |   |
#            |
#            |
#     =========
#
# -----
# Esta letra ya la has acertado
# Te has equivocado chaval
# Intentos restantes: 3
# Letras descartadas: d, s, s
#
# Palabra: _ _ s _ _ _ h _ s
#
#
#        +---+
#        |   |
#        O   |
#       /|   |
#            |
#            |
#     =========
#
# -----
# Te has equivocado chaval
# Intentos restantes: 2
# Letras descartadas: d, s, s, v
#
# Palabra: _ _ s _ _ _ h _ s
#
#
#        +---+
#        |   |
#        O   |
#       /|\  |
#            |
#            |
#     =========
#
# -----
# Esta letra ya la has acertado
# Te has equivocado chaval
# Intentos restantes: 1
# Letras descartadas: d, s, s, v, s
#
# Palabra: _ _ s _ _ _ h _ s
#
#
#        +---+
#        |   |
#        O   |
#       /|\  |
#       /    |
#            |
#     =========
#
# -----
# Te has equivocado chaval
# Intentos restantes: 0
# Letras descartadas: d, s, s, v, s, a
#
# Palabra: _ _ s _ _ _ h _ s
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 123
#     121     mostrar_estado(num_intentos,letras_descartadas,palabra_oculta,dibujo_ahorcado)
#     122 else:
# --> 123     mostrar_estado(num_intentos,letras_descartadas,palabra_oculta,dibujo_ahorcado)
#     124     print(f'\n ¡Mejor suerte la próxima!'
#     125         '''\n
#     126        +---+
#    (...)
#     132     =========
#     133     ''')
#
# Cell In[20], line 73, in mostrar_estado(intentos, descartes, ocultas, dibujo)
#      71 print(f'Letras descartadas: {", ".join(descartes)}\n')
#      72 print(f'Palabra: {" ".join(ocultas)}\n')
# ---> 73 print(dibujo[6 - intentos])
#
# IndexError: list index out of range

# %%
import random

def jugar(lista_palabras):

    dibujo_ahorcado = [
        '''
        +---+
        |   |
            |
            |
            |
            |
        =========
        ''',
        '''
        +---+
        |   |
        O   |
            |
            |
            |
        =========
        ''',
        '''
        +---+
        |   |
        O   |
        |   |
            |
            |
        =========
        ''',
        '''
        +---+
        |   |
        O   |
        /|   |
            |
            |
        =========
        ''',
        '''
        +---+
        |   |
        O   |
        /|\  |
            |
            |
        =========
        ''',
        '''
        +---+
        |   |
        O   |
        /|\  |
        /    |
            |
        =========
        ''',
    ]

    palabra_elegida = list(random.choice(lista_palabras))
    palabra_oculta =['_']*len(palabra_elegida)
    num_intentos = 6
    lista_abecedario = list('abcdefghijklmnñopqrstuvwxyz')
    letras_descartadas = []


    print('😎 BIENVENIDO AL JUEGO DEL AHORCADO, Hackio Edition 😎 \n')
    print('Reglas del juego: Introduce letras para adivinar la palabra oculta .')
    print(f'Tienes {num_intentos} intentos. ¡Buena suerte!')

    while num_intentos > 0 and '_' in palabra_oculta:
        mostrar_estado(num_intentos,letras_descartadas,palabra_oculta,dibujo_ahorcado)
        print('-----')
        letra_elegida = input('Introduce una letra:').lower()

        while not opcion_letra(letra_elegida, lista_abecedario, palabra_oculta,letras_descartadas):
            letra_elegida = input('Introduce otra letra').lower()

        if letra_elegida in palabra_elegida:
            gestion(letra_elegida,palabra_elegida,palabra_oculta)
            print('Has acertado la letra')
        else: 
            print('Te has equivocado chaval')
            letras_descartadas.append(letra_elegida)
            num_intentos -= 1
            ### debo de agregar la visual del ahorcado (hago un contador de la lista de dibujos que vaya aumentando )
            ### me falta imprimir la palabra completa
    if '_' not in palabra_oculta: ### agregar que cuando los intentos y el contador sean iguales, se pierde
        print('\n🏆¡ENHORABUENA!🏆\n🏆¡HAS GANADO EL JUEGO!🏆')
        mostrar_estado(num_intentos,letras_descartadas,palabra_oculta,dibujo_ahorcado)
    else:
        mostrar_estado(num_intentos,letras_descartadas,palabra_oculta,dibujo_ahorcado)
        print(f'\n ¡Mejor suerte la próxima!'
            '''\n
        +---+
        |   |
        💀   |
        /|\  |
        / \  |
            |
        =========
        ''')

def mostrar_estado(intentos, descartes,ocultas,dibujo):

    print(f'Intentos restantes: {intentos}')
    print(f'Letras descartadas: {", ".join(descartes)}\n')
    print(f'Palabra: {" ".join(ocultas)}\n')
    print(dibujo[6 - intentos])


def opcion_letra(letra, abecedario,pal_oculta,let_descartadas):
    if len(letra) != 1:
        print('Has seleccionado más de una letra')
        return False
    elif letra not in abecedario:
        print('Has seleccionado una letra fuera del abecedario')
        return False
    elif letra in pal_oculta:
        print('Esta letra ya la has acertado')
        return True
    elif letra in let_descartadas:
        print('Esta letra ya la habías dicho')
        return False
    else:
        return True

def gestion(letra,p_e,p_o):
        for i in range(len(p_e)):
            if p_e[i] == letra:
                p_o[i] = letra
                p_e[i] = '_'

# %%
lista_palabras = ['python', 'desarrollador', 'programacion']
jugar(lista_palabras)
# Out:
# BIENVENIDO AL JUEGO DEL AHORCADO, Hackio Edition 😎
#
# Reglas del juego: Introduce letras para adivinar la palabra oculta .
# Tienes 6 intentos. ¡Buena suerte!
# Intentos restantes: 6
# Letras descartadas:
#
# Palabra: _ _ _ _ _ _ _ _ _ _ _ _ _
#
#
#         +---+
#         |   |
#             |
#             |
#             |
#             |
#         =========
#
# -----
# Has acertado la letra
# Intentos restantes: 6
# Letras descartadas:
#
# Palabra: _ _ _ _ _ _ o _ _ _ _ o _
#
#
#         +---+
#         |   |
#             |
#             |
#             |
#             |
#         =========
#
# -----
# Te has equivocado chaval
# Intentos restantes: 5
# Letras descartadas: p
#
# Palabra: _ _ _ _ _ _ o _ _ _ _ o _
#
#
#         +---+
#         |   |
#         O   |
#             |
#             |
#             |
#         =========
#
# -----
# Has acertado la letra
# Intentos restantes: 5
# Letras descartadas: p
#
# Palabra: _ _ _ _ r r o _ _ _ _ o r
#
#
#         +---+
#         |   |
#         O   |
#             |
#             |
#             |
#         =========
#
# -----
# Te has equivocado chaval
# Intentos restantes: 4
# Letras descartadas: p, m
#
# Palabra: _ _ _ _ r r o _ _ _ _ o r
#
#
#         +---+
#         |   |
#         O   |
#         |   |
#             |
#             |
#         =========
#
# -----
# Has acertado la letra
# Intentos restantes: 4
# Letras descartadas: p, m
#
# Palabra: d _ _ _ r r o _ _ _ d o r
#
#
#         +---+
#         |   |
#         O   |
#         |   |
#             |
#             |
#         =========
#
# -----
# Has acertado la letra
# Intentos restantes: 4
# Letras descartadas: p, m
#
# Palabra: d e _ _ r r o _ _ _ d o r
#
#
#         +---+
#         |   |
#         O   |
#         |   |
#             |
#             |
#         =========
#
# -----
# Has acertado la letra
# Intentos restantes: 4
# Letras descartadas: p, m
#
# Palabra: d e s _ r r o _ _ _ d o r
#
#
#         +---+
#         |   |
#         O   |
#         |   |
#             |
#             |
#         =========
#
# -----
# Has acertado la letra
# Intentos restantes: 4
# Letras descartadas: p, m
#
# Palabra: d e s a r r o _ _ a d o r
#
#
#         +---+
#         |   |
#         O   |
#         |   |
#             |
#             |
#         =========
#
# -----
# Has acertado la letra
#
# 🏆¡ENHORABUENA!🏆
# 🏆¡HAS GANADO EL JUEGO!🏆
# Intentos restantes: 4
# Letras descartadas: p, m
#
# Palabra: d e s a r r o l l a d o r
#
#
#         +---+
#         |   |
#         O   |
#         |   |
#             |
#             |
#         =========
